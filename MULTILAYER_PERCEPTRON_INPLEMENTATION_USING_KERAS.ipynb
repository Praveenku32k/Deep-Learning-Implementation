# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenku32k/Deep-Learning-Implementation/blob/main/MULTILAYER_PERCEPTRON_INPLEMENTATION_USING_KERAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ROOT="/content/drive/MyDrive/Artifical_Neural_Network_class_Lab/KERAS IMPLEMENTATION"

# %%
import os

os.chdir(ROOT)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Artifical_Neural_Network_class_Lab/KERAS IMPLEMENTATION'

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
tf.keras.__version__
# Out:
# '2.6.0'

# %%
tf.config.list_physical_devices("GPU")# Checking for version
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.list_physical_devices("CPU")
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
CheckList = ["GPU", "CPU"]
for device in CheckList:
  out_=tf.config.list_physical_devices(device)
  if len(out_)>0:
    print(f"{device}  is available")
    print("details",out_)
  else:
    print(f"{device } is not available ")
# Out:
# GPU  is available
# details [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# CPU  is available
# details [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Multi class classification

# %%
mnist=tf.keras.datasets.mnist
(X_train_full,y_train_full),(X_test,y_test)=mnist.load_data()

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
y_train_full.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
type(X_train_full)
# Out:
# numpy.ndarray

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %%
X_valid, X_train=X_train_full[:5000] / 255.0 ,X_train_full[5000:]/255.0
y_valid, y_train =y_train_full[:5000],y_train_full[5000:]

# %%
plt.imshow(X_train[11000],cmap="binary")
plt.axis("off")
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(X_train[0],annot=True,cmap="binary")

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(X_train[0],annot=True)

# %%
LAYERS=[tf.keras.layers.Flatten(input_shape=[28,28],name="inputLayer"),
        tf.keras.layers.Dense(300,activation="relu",name="hiddenLayer1"),
        tf.keras.layers.Dense(100,activation="relu",name="hiddenLayer2"),
        tf.keras.layers.Dense(10,activation="softmax",name="outputLaye")]

# %%
model_clf=tf.keras.models.Sequential(LAYERS)

# %%
model_clf.layers

# %%
model_clf.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# inputLayer (Flatten)         (None, 784)               0
# _________________________________________________________________
# hiddenLayer1 (Dense)         (None, 300)               235500
# _________________________________________________________________
# hiddenLayer2 (Dense)         (None, 100)               30100
# _________________________________________________________________
# outputLaye (Dense)           (None, 10)                1010
# ...
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
784*300+300
# Out:
# 235500

# %%
300*100+100
# Out:
# 30100

# %%
100*10+10
# Out:
# 1010

# %%
235500+30100+1010 #Total no of paramerter
# Out:
# 266610
